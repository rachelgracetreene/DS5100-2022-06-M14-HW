# %% [markdown]
# # Metadata
#
# ```yaml
# Course:  DS 5100
# Module:  14 Python Packages
# Topic:   HW Package Booklover
# Author:  R.C. Alvarado
# Date:    11 July 2022
# ```

# %% [markdown]
# # Student Metadata
#
# * Name: Rachel Grace
# * NetID: rg5xm

# %% [markdown]
# # Instructions
#
# Follow the recipe we used in class to package the code you wrote for `HW09` -- `booklover.py` and `booklover_test.py`.
#
# Here is the recipe:
# * Create a new git repo for your package.
# * Create and edit the required files and directories for your package and move the booklover modules there.
# * Stage, commit, and push all the files you've created.
# * Install your package with pip.
# * Outside of your package dir, write a script to test your method.
#
# Put this notebook in your repo. This will allow you to execute bash commands and capture the outpunt directly in the notebook.
#
# **TOTAL: 8 POINTS**

# %% [markdown]
# # Q1
#
# (5 points)
#
# Show the directory structure of your repo by running this command from the root of your repo:

# %%
from IPython.display import Image

PATH = "C:\\Users\\Rachel\\OneDrive\\MSDS\\DS 5100\\"

Image(PATH + 'Q1.png')

# %% [markdown]
# # Q2
#
# (1 point)
#
# Put the URL of your GitHub repo here. Just paste it into a Markdown cell.

# %% [markdown]
# URL: https://github.com/rachelegrace/DS5100-2022-06-M14-HW

# %% [markdown]
# # Q3
#
# (1 point)
#
# Show the results of installing your package.
#
# ```bash
# !pip install -e .
# ```

# %%
pip install -e .
# Out:
# Obtaining file:///C:/Users/Rachel/Documents/GitHub/DS5100-2022-06-M14-HW
# Installing collected packages: M14
#   Attempting uninstall: M14
#     Found existing installation: M14 0.1
#     Uninstalling M14-0.1:
#       Successfully uninstalled M14-0.1
#   Running setup.py develop for M14
# Successfully installed M14-0.1
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Q4
#
# (1 point)
#
# Create a file outside your repo (one level up) to test your package.
#
# Import the package and run it. Specifically, create a BookLover object, add a book, and then print number books read.
#
# Show the output of running the file below, using a command like the following:
#
# ```bash
# !python ../book_lover_demo.py
# ```

# %%
PATH = "C:\\Users\\Rachel\\OneDrive\\MSDS\\DS 5100\\"

Image(PATH + 'Q4.png')
